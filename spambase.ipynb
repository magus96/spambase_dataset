# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# %%
columnss = ['word_freq_make',
            'word_freq_address',
            'word_freq_all', 
            'word_freq_3d',
            'word_freq_our',
            'word_freq_over',
            'word_freq_remove',
            'word_freq_internet',
            'word_freq_order',
            'word_freq_mail',
            'word_freq_receive',
            'word_freq_will',
            'word_freq_people',
            'word_freq_report',
            'word_freq_addresses',
            'word_freq_free',
            'word_freq_business',
            'word_freq_email',
            'word_freq_you',
            'word_freq_credit',
            'word_freq_your',
            'word_freq_font',
            'word_freq_000',
            'word_freq_money',
            'word_freq_hp',
            'word_freq_hpl',
            'word_freq_george',
            'word_freq_650',
            'word_freq_lab',
            'word_freq_labs',
            'word_freq_telnet',
            'word_freq_857',
            'word_freq_data',
            'word_freq_415',
            'word_freq_85',
            'word_freq_technology',
            'word_freq_1999',
            'word_freq_parts',
            'word_freq_pm',
            'word_freq_direct',
            'word_freq_cs',
            'word_freq_meeting',
            'word_freq_original',
            'word_freq_project',
            'word_freq_re',
            'word_freq_edu',
            'word_freq_table',
            'word_freq_conference',
            'char_freq_;',
            'char_freq_(',
            'char_freq_[',
            'char_freq_!',
            'char_freq_$',
            'char_freq_#',
            'capital_run_length_average',
            'capital_run_length_longest',
            'capital_run_length_total',
            'SPAM'
]
sbase=pd.read_csv("D:\\Spambase\\Data\\spambase.data",header=None,names=columnss)
sbase.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...   char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...          0.00        0.000
# ...

# %%
train,test=train_test_split(sbase,test_size=0.4,train_size=0.6,random_state=60)
y_train=train.SPAM
X_train=train.drop('SPAM',1)
y_test=test.SPAM
X_test=test.drop('SPAM',1)
print(y_test)
# Out:
# 3285    0
# 3596    0
# 4221    0
# 3391    0
# 696     1
# 2923    0
# 2702    0
# 3940    0
# 3438    0
# 1177    1
# 699     1
# 2351    0
# 931     1
# 851     1
# 3435    0
# 3637    0
# 2149    0
# 2885    0
# 545     1
# 2570    0
# 55      1
# 4597    0
# 1094    1
# 1026    1
# 3012    0
# 1885    0
# 2777    0
# 889     1
# 2733    0
# 3535    0
#        ..
# 3783    0
# 1907    0
# 2532    0
# 2997    0
# 3278    0
# 15      1
# 4555    0
# 3659    0
# 3114    0
# 4561    0
# 1926    0
# 1216    1
# 4356    0
# 4214    0
# 590     1
# 3664    0
# 4102    0
# 1170    1
# 4246    0
# 2547    0
# 990     1
# 3955    0
# 2497    0
# 2994    0
# 1965    0
# 2101    0
# 3795    0
# 4293    0
# 2424    0
# 538     1
# Name: SPAM, Length: 1841, dtype: int64

# %%
sbase.corr(method='pearson')
# Out:
#                             word_freq_make  word_freq_address  word_freq_all  \
# word_freq_make                    1.000000          -0.016759       0.065627
# word_freq_address                -0.016759           1.000000      -0.033526
# word_freq_all                     0.065627          -0.033526       1.000000
# word_freq_3d                      0.013273          -0.006923      -0.020246
# word_freq_our                     0.023119          -0.023760       0.077734
# word_freq_over                    0.059674          -0.024840       0.087564
# word_freq_remove                  0.007669           0.003918       0.036677
# word_freq_internet               -0.003950          -0.016280       0.012003
# word_freq_order                   0.106263          -0.003826       0.093786
# word_freq_mail                    0.041198           0.032962       0.032075
# word_freq_receive                 0.188459          -0.006864       0.048254
# ...

# %%
#we checked correlation nd found that word frequencies have highest impact on prediction wth some other columns which well retain
n_columnss=[
            'word_freq_make',
            'word_freq_address',
            'word_freq_all', 
            'word_freq_3d',
            'word_freq_our',
            'word_freq_over',
            'word_freq_remove',
            'word_freq_internet',
            'word_freq_order',
            'word_freq_mail',
            'word_freq_receive',
            'word_freq_will',
            'word_freq_people',
            'word_freq_report',
            'word_freq_addresses',
            'word_freq_free',
            'word_freq_business',
            'word_freq_email',
            'word_freq_you',
            'word_freq_credit',
            'word_freq_your',
            'word_freq_font',
            'word_freq_000',
            'word_freq_money',
            'word_freq_hp',
            'word_freq_hpl',
            'word_freq_george',
            'word_freq_650',
            'word_freq_lab',
            'word_freq_labs',
            'word_freq_telnet',
            'word_freq_857',
            'word_freq_data',
            'word_freq_415',
            'word_freq_85',
            'word_freq_technology',
            'word_freq_1999',
            'word_freq_parts',
            'word_freq_pm',
            'word_freq_direct',
            'word_freq_cs',
            'word_freq_meeting',
            'word_freq_original',
            'word_freq_project',
            'word_freq_re',
            'word_freq_edu',
            'word_freq_table',
            'word_freq_conference',
            'char_freq_!',
            'char_freq_$',
            'SPAM'
]

# %%
ntrain,ntest=train_test_split(sbase[n_columnss],test_size=0.6,train_size=0.4,random_state=60)
nX_train=ntrain.drop('SPAM',1)
ny_train=ntrain.SPAM
nX_test=ntest.drop('SPAM',1)
ny_test=ntest.SPAM

# %%
model=MultinomialNB()
model.fit(nX_train,ny_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
model.score(nX_test,ny_test)
# Out:
# 0.8685258964143426
